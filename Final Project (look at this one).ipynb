# %%
# %matplotlib inline
 
import matplotlib.pyplot as plt
import numpy as np
import os
import pprint
pp = pprint.PrettyPrinter(indent=4)

# %%
import joblib
from skimage.io import imread
from skimage.transform import resize
 
def resize_all(src, pklname, include, width=150, height=None):
    """
    load images from path, resize them and write them as arrays to a dictionary, 
    together with labels and metadata. The dictionary is written to a pickle file 
    named '{pklname}_{width}x{height}px.pkl'.
     
    Parameter
    ---------
    src: str
        path to data
    pklname: str
        path to output file
    width: int
        target width of the image in pixels
    include: set[str]
        set containing str
    """
     
    height = height if height is not None else width
     
    data = dict()
    data['description'] = 'resized ({0}x{1})car images in rgb'.format(int(width), int(height))
    data['label'] = []
    data['filename'] = []
    data['data'] = []   
     
    pklname = f"{pklname}_{width}x{height}px.pkl"
 
    # read all images in PATH, resize and write to DESTINATION_PATH
    for subdir in os.listdir(src):
        if subdir in include:
            print(subdir)
            current_path = os.path.join(src, subdir)
 
            for file in os.listdir(current_path):
                if file[-3:] in {'jpg'}:
                    im = imread(os.path.join(current_path, file))
                    im = resize(im, (width, height)) #[:,:,::-1]
                    data['label'].append(subdir[:-4])
                    data['filename'].append(file)
                    data['data'].append(im)
 
        joblib.dump(data, pklname)

# %%
# Link: https://www.analyticsvidhya.com/blog/2021/06/how-to-load-kaggle-datasets-directly-into-google-colab/
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# ! kaggle datasets download jutrera/stanford-car-dataset-by-classes-folder
# ! unzip stanford-car-dataset-by-classes-folder.zip

# %%
# data_path = "archive/car_data/car_data/train"
data_path = "/content/car_data/car_data/train"
os.listdir(data_path)
# Out:
# ['Honda Accord Coupe 2012',
#  'Rolls-Royce Phantom Drophead Coupe Convertible 2012',
#  'Bentley Mulsanne Sedan 2011',
#  'Dodge Charger SRT-8 2009',
#  'GMC Terrain SUV 2012',
#  'BMW 3 Series Wagon 2012',
#  'GMC Acadia SUV 2012',
#  'Toyota Corolla Sedan 2012',
#  'Chevrolet Express Van 2007',
#  'Aston Martin V8 Vantage Coupe 2012',
#  'Mercedes-Benz E-Class Sedan 2012',
#  'Acura TL Type-S 2008',
#  'Rolls-Royce Phantom Sedan 2012',
#  'Dodge Sprinter Cargo Van 2009',
#  'Mercedes-Benz 300-Class Convertible 1993',
#  'Jaguar XK XKR 2012',
#  'Maybach Landaulet Convertible 2012',
#  'Chevrolet Corvette Ron Fellows Edition Z06 2007',
#  'Lamborghini Aventador Coupe 2012',
#  'Fisker Karma Sedan 2012',
#  'BMW 6 Series Convertible 2007',
#  'Jeep Liberty SUV 2012',
#  'Nissan 240SX Coupe 1998',
#  'Rolls-Royce Ghost Sedan 2012',
#  'Chevrolet Traverse SUV 2012',
#  'Hyundai Santa Fe SUV 2012',
#  'Audi TT RS Coupe 2012',
#  'Hyundai Azera Sedan 2012',
#  'Audi R8 Coupe 2012',
#  'Dodge Caliber Wagon 2007',
#  'Ferrari 458 Italia Convertible 2012',
#  'Lamborghini Diablo Coupe 2001',
#  'Ram C-V Cargo Van Minivan 2012',
#  'Bentley Continental GT Coupe 2012',
#  'Lincoln Town Car Sedan 2011',
#  'BMW X3 SUV 2012',
#  'Bentley Arnage Sedan 2009',
#  'smart fortwo Convertible 2012',
#  'Audi TT Hatchback 2011',
#  'Audi S5 Convertible 2012',
#  'BMW 1 Series Coupe 2012',
#  'Dodge Ram Pickup 3500 Crew Cab 2010',
#  'Dodge Caravan Minivan 1997',
#  'Chevrolet Sonic Sedan 2012',
#  'Tesla Model S Sedan 2012',
#  'Audi 100 Sedan 1994',
#  'Bentley Continental Flying Spur Sedan 2007',
#  'Suzuki SX4 Sedan 2012',
#  'Volkswagen Golf Hatchback 1991',
#  'Lamborghini Reventon Coupe 2008',
#  'Hyundai Tucson SUV 2012',
#  'Daewoo Nubira Wagon 2002',
#  'Mercedes-Benz S-Class Sedan 2012',
#  'Chrysler Crossfire Convertible 2008',
#  'Ford F-150 Regular Cab 2012',
#  'BMW ActiveHybrid 5 Sedan 2012',
#  'Volkswagen Beetle Hatchback 2012',
#  'Dodge Magnum Wagon 2008',
#  'Chrysler Aspen SUV 2009',
#  'Chevrolet Malibu Sedan 2007',
#  'Ford Edge SUV 2012',
#  'Toyota 4Runner SUV 2012',
#  'Audi TTS Coupe 2012',
#  'Dodge Dakota Club Cab 2007',
#  'Eagle Talon Hatchback 1998',
#  'McLaren MP4-12C Coupe 2012',
#  'Isuzu Ascender SUV 2008',
#  'Buick Enclave SUV 2012',
#  'Honda Accord Sedan 2012',
#  'Audi S6 Sedan 2011',
#  'Ferrari FF Coupe 2012',
#  'GMC Canyon Extended Cab 2012',
#  'Chevrolet Malibu Hybrid Sedan 2010',
#  'FIAT 500 Abarth 2012',
#  'Suzuki Aerio Sedan 2007',
#  'Chevrolet Express Cargo Van 2007',
#  'AM General Hummer SUV 2000',
#  'Acura ZDX Hatchback 2012',
#  'Dodge Ram Pickup 3500 Quad Cab 2009',
#  'Bentley Continental GT Coupe 2007',
#  'Chrysler PT Cruiser Convertible 2008',
#  'Audi 100 Wagon 1994',
#  'Dodge Charger Sedan 2012',
#  'BMW X5 SUV 2007',
#  'Hyundai Sonata Hybrid Sedan 2012',
#  'Infiniti QX56 SUV 2011',
#  'Bugatti Veyron 16.4 Convertible 2009',
#  'Chevrolet Avalanche Crew Cab 2012',
#  'HUMMER H2 SUT Crew Cab 2009',
#  'Geo Metro Convertible 1993',
#  'Chrysler Town and Country Minivan 2012',
#  'Volvo XC90 SUV 2007',
#  'Buick Regal GS 2012',
#  'Jeep Wrangler SUV 2012',
#  'Nissan NV Passenger Van 2012',
#  'Land Rover Range Rover SUV 2012',
#  'Mercedes-Benz SL-Class Coupe 2009',
#  'Dodge Dakota Crew Cab 2010',
#  'Spyker C8 Convertible 2009',
#  'BMW X6 SUV 2012',
#  'Jeep Patriot SUV 2012',
#  'Chevrolet Silverado 1500 Classic Extended Cab 2007',
#  'Jeep Compass SUV 2012',
#  'Chevrolet Monte Carlo Coupe 2007',
#  'Chevrolet HHR SS 2010',
#  'Hyundai Genesis Sedan 2012',
#  'Suzuki Kizashi Sedan 2012',
#  'FIAT 500 Convertible 2012',
#  'Scion xD Hatchback 2012',
#  'Ford GT Coupe 2006',
#  'Honda Odyssey Minivan 2007',
#  'BMW M5 Sedan 2010',
#  'Dodge Caliber Wagon 2012',
#  'BMW 1 Series Convertible 2012',
#  'Ford Fiesta Sedan 2012',
#  'Mercedes-Benz Sprinter Van 2012',
#  'Honda Odyssey Minivan 2012',
#  'Toyota Sequoia SUV 2012',
#  'Infiniti G Coupe IPL 2012',
#  'Dodge Durango SUV 2012',
#  'Buick Verano Sedan 2012',
#  'Ford Freestar Minivan 2007',
#  'Buick Rainier SUV 2007',
#  'Cadillac CTS-V Sedan 2012',
#  'Lamborghini Gallardo LP 570-4 Superleggera 2012',
#  'Bugatti Veyron 16.4 Coupe 2009',
#  'Hyundai Accent Sedan 2012',
#  'Cadillac SRX SUV 2012',
#  'Aston Martin V8 Vantage Convertible 2012',
#  'BMW M6 Convertible 2010',
#  'Jeep Grand Cherokee SUV 2012',
#  'Chevrolet Corvette Convertible 2012',
#  'Audi V8 Sedan 1994',
#  'Acura Integra Type R 2001',
#  'HUMMER H3T Crew Cab 2010',
#  'Chevrolet Cobalt SS 2010',
#  'Ford Mustang Convertible 2007',
#  'Chevrolet Impala Sedan 2007',
#  'Chrysler Sebring Convertible 2010',
#  'Chevrolet Camaro Convertible 2012',
#  'Volvo C30 Hatchback 2012',
#  'Nissan Juke Hatchback 2012',
#  'Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
#  'Audi S4 Sedan 2012',
#  'Chevrolet TrailBlazer SS 2009',
#  'Aston Martin Virage Coupe 2012',
#  'Spyker C8 Coupe 2009',
#  'Ford F-150 Regular Cab 2007',
#  'Dodge Challenger SRT8 2011',
#  'Audi A5 Coupe 2012',
#  'Mazda Tribute SUV 2011',
#  'Chevrolet Tahoe Hybrid SUV 2012',
#  'Land Rover LR2 SUV 2012',
#  'Hyundai Veracruz SUV 2012',
#  'Ford Focus Sedan 2007',
#  'BMW M3 Coupe 2012',
#  'Mercedes-Benz C-Class Sedan 2012',
#  'Cadillac Escalade EXT Crew Cab 2007',
#  'BMW 3 Series Sedan 2012',
#  'Mitsubishi Lancer Sedan 2012',
#  'Hyundai Elantra Sedan 2007',
#  'Toyota Camry Sedan 2012',
#  'Acura RL Sedan 2012',
#  'Audi S5 Coupe 2012',
#  'Hyundai Veloster Hatchback 2012',
#  'Aston Martin Virage Convertible 2012',
#  'Chevrolet Corvette ZR1 2012',
#  'MINI Cooper Roadster Convertible 2012',
#  'Bentley Continental Supersports Conv. Convertible 2012',
#  'Ford E-Series Wagon Van 2012',
#  'Audi RS 4 Convertible 2008',
#  'Acura TSX Sedan 2012',
#  'Volkswagen Golf Hatchback 2012',
#  'Audi S4 Sedan 2007',
#  'Hyundai Sonata Sedan 2012',
#  'Volvo 240 Sedan 1993',
#  'Acura TL Sedan 2012',
#  'Hyundai Elantra Touring Hatchback 2012',
#  'Chevrolet Silverado 2500HD Regular Cab 2012',
#  'GMC Yukon Hybrid SUV 2012',
#  'Ford F-450 Super Duty Crew Cab 2012',
#  'Chrysler 300 SRT-8 2010',
#  'GMC Savana Van 2012',
#  'Chevrolet Silverado 1500 Regular Cab 2012',
#  'Dodge Journey SUV 2012',
#  'Dodge Durango SUV 2007',
#  'Ford Ranger SuperCab 2011',
#  'Ford Expedition EL SUV 2009',
#  'Suzuki SX4 Hatchback 2012',
#  'Porsche Panamera Sedan 2012',
#  'Ferrari California Convertible 2012',
#  'Plymouth Neon Coupe 1999',
#  'Chevrolet Silverado 1500 Extended Cab 2012',
#  'Ferrari 458 Italia Coupe 2012',
#  'Nissan Leaf Hatchback 2012',
#  'BMW Z4 Convertible 2012']

# %%
base_name = 'train'
width = 80

include = {'Acura Integra Type R 2001',
 'Acura RL Sedan 2012',
 'Acura TL Sedan 2012',
 'Acura TL Type-S 2008',
 'Acura TSX Sedan 2012',
 'Acura ZDX Hatchback 2012',
 'AM General Hummer SUV 2000',
 'Aston Martin V8 Vantage Convertible 2012',
 'Aston Martin V8 Vantage Coupe 2012',
 'Aston Martin Virage Convertible 2012',
 'Aston Martin Virage Coupe 2012',
 'Audi 100 Sedan 1994',
 'Audi 100 Wagon 1994',
 'Audi A5 Coupe 2012',
 'Audi R8 Coupe 2012',
 'Audi RS 4 Convertible 2008',
 'Audi S4 Sedan 2007',
 'Audi S4 Sedan 2012',
 'Audi S5 Convertible 2012',
 'Audi S5 Coupe 2012',
 'Audi S6 Sedan 2011',
 'Audi TT Hatchback 2011',
 'Audi TT RS Coupe 2012',
 'Audi TTS Coupe 2012',
 'Audi V8 Sedan 1994',
 'Bentley Arnage Sedan 2009',
 'Bentley Continental Flying Spur Sedan 2007',
 'Bentley Continental GT Coupe 2007',
 'Bentley Continental GT Coupe 2012',
 'Bentley Continental Supersports Conv. Convertible 2012',
 'Bentley Mulsanne Sedan 2011',
 'BMW 1 Series Convertible 2012',
 'BMW 1 Series Coupe 2012',
 'BMW 3 Series Sedan 2012',
 'BMW 3 Series Wagon 2012',
 'BMW 6 Series Convertible 2007',
 'BMW ActiveHybrid 5 Sedan 2012',
 'BMW M3 Coupe 2012',
 'BMW M5 Sedan 2010',
 'BMW M6 Convertible 2010',
 'BMW X3 SUV 2012',
 'BMW X5 SUV 2007',
 'BMW X6 SUV 2012',
 'BMW Z4 Convertible 2012',
 'Bugatti Veyron 16.4 Convertible 2009',
 'Bugatti Veyron 16.4 Coupe 2009',
 'Buick Enclave SUV 2012',
 'Buick Rainier SUV 2007',
 'Buick Regal GS 2012',
 'Buick Verano Sedan 2012',
 'Cadillac CTS-V Sedan 2012',
 'Cadillac Escalade EXT Crew Cab 2007',
 'Cadillac SRX SUV 2012',
 'Chevrolet Avalanche Crew Cab 2012',
 'Chevrolet Camaro Convertible 2012',
 'Chevrolet Cobalt SS 2010',
 'Chevrolet Corvette Convertible 2012',
 'Chevrolet Corvette Ron Fellows Edition Z06 2007',
 'Chevrolet Corvette ZR1 2012',
 'Chevrolet Express Cargo Van 2007',
 'Chevrolet Express Van 2007',
 'Chevrolet HHR SS 2010',
 'Chevrolet Impala Sedan 2007',
 'Chevrolet Malibu Hybrid Sedan 2010',
 'Chevrolet Malibu Sedan 2007',
 'Chevrolet Monte Carlo Coupe 2007',
 'Chevrolet Silverado 1500 Classic Extended Cab 2007',
 'Chevrolet Silverado 1500 Extended Cab 2012',
 'Chevrolet Silverado 1500 Hybrid Crew Cab 2012',
 'Chevrolet Silverado 1500 Regular Cab 2012',
 'Chevrolet Silverado 2500HD Regular Cab 2012',
 'Chevrolet Sonic Sedan 2012',
 'Chevrolet Tahoe Hybrid SUV 2012',
 'Chevrolet TrailBlazer SS 2009',
 'Chevrolet Traverse SUV 2012',
 'Chrysler 300 SRT-8 2010',
 'Chrysler Aspen SUV 2009',
 'Chrysler Crossfire Convertible 2008',
 'Chrysler PT Cruiser Convertible 2008',
 'Chrysler Sebring Convertible 2010',
 'Chrysler Town and Country Minivan 2012',
 'Daewoo Nubira Wagon 2002',
 'Dodge Caliber Wagon 2007',
 'Dodge Caliber Wagon 2012',
 'Dodge Caravan Minivan 1997',
 'Dodge Challenger SRT8 2011',
 'Dodge Charger Sedan 2012',
 'Dodge Charger SRT-8 2009',
 'Dodge Dakota Club Cab 2007',
 'Dodge Dakota Crew Cab 2010',
 'Dodge Durango SUV 2007',
 'Dodge Durango SUV 2012',
 'Dodge Journey SUV 2012',
 'Dodge Magnum Wagon 2008',
 'Dodge Ram Pickup 3500 Crew Cab 2010',
 'Dodge Ram Pickup 3500 Quad Cab 2009',
 'Dodge Sprinter Cargo Van 2009',
 'Eagle Talon Hatchback 1998',
 'Ferrari 458 Italia Convertible 2012',
 'Ferrari 458 Italia Coupe 2012',
 'Ferrari California Convertible 2012',
 'Ferrari FF Coupe 2012',
 'FIAT 500 Abarth 2012',
 'FIAT 500 Convertible 2012',
 'Fisker Karma Sedan 2012',
 'Ford E-Series Wagon Van 2012',
 'Ford Edge SUV 2012',
 'Ford Expedition EL SUV 2009',
 'Ford F-150 Regular Cab 2007',
 'Ford F-150 Regular Cab 2012',
 'Ford F-450 Super Duty Crew Cab 2012',
 'Ford Fiesta Sedan 2012',
 'Ford Focus Sedan 2007',
 'Ford Freestar Minivan 2007',
 'Ford GT Coupe 2006',
 'Ford Mustang Convertible 2007',
 'Ford Ranger SuperCab 2011',
 'Geo Metro Convertible 1993',
 'GMC Acadia SUV 2012',
 'GMC Canyon Extended Cab 2012',
 'GMC Savana Van 2012',
 'GMC Terrain SUV 2012',
 'GMC Yukon Hybrid SUV 2012',
 'Honda Accord Coupe 2012',
 'Honda Accord Sedan 2012',
 'Honda Odyssey Minivan 2007',
 'Honda Odyssey Minivan 2012',
 'HUMMER H2 SUT Crew Cab 2009',
 'HUMMER H3T Crew Cab 2010',
 'Hyundai Accent Sedan 2012',
 'Hyundai Azera Sedan 2012',
 'Hyundai Elantra Sedan 2007',
 'Hyundai Elantra Touring Hatchback 2012',
 'Hyundai Genesis Sedan 2012',
 'Hyundai Santa Fe SUV 2012',
 'Hyundai Sonata Hybrid Sedan 2012',
 'Hyundai Sonata Sedan 2012',
 'Hyundai Tucson SUV 2012',
 'Hyundai Veloster Hatchback 2012',
 'Hyundai Veracruz SUV 2012',
 'Infiniti G Coupe IPL 2012',
 'Infiniti QX56 SUV 2011',
 'Isuzu Ascender SUV 2008',
 'Jaguar XK XKR 2012',
 'Jeep Compass SUV 2012',
 'Jeep Grand Cherokee SUV 2012',
 'Jeep Liberty SUV 2012',
 'Jeep Patriot SUV 2012',
 'Jeep Wrangler SUV 2012',
 'Lamborghini Aventador Coupe 2012',
 'Lamborghini Diablo Coupe 2001',
 'Lamborghini Gallardo LP 570-4 Superleggera 2012',
 'Lamborghini Reventon Coupe 2008',
 'Land Rover LR2 SUV 2012',
 'Land Rover Range Rover SUV 2012',
 'Lincoln Town Car Sedan 2011',
 'Maybach Landaulet Convertible 2012',
 'Mazda Tribute SUV 2011',
 'McLaren MP4-12C Coupe 2012',
 'Mercedes-Benz 300-Class Convertible 1993',
 'Mercedes-Benz C-Class Sedan 2012',
 'Mercedes-Benz E-Class Sedan 2012',
 'Mercedes-Benz S-Class Sedan 2012',
 'Mercedes-Benz SL-Class Coupe 2009',
 'Mercedes-Benz Sprinter Van 2012',
 'MINI Cooper Roadster Convertible 2012',
 'Mitsubishi Lancer Sedan 2012',
 'Nissan 240SX Coupe 1998',
 'Nissan Juke Hatchback 2012',
 'Nissan Leaf Hatchback 2012',
 'Nissan NV Passenger Van 2012',
 'Plymouth Neon Coupe 1999',
 'Porsche Panamera Sedan 2012',
 'Ram C-V Cargo Van Minivan 2012',
 'Rolls-Royce Ghost Sedan 2012',
 'Rolls-Royce Phantom Drophead Coupe Convertible 2012',
 'Rolls-Royce Phantom Sedan 2012',
 'Scion xD Hatchback 2012',
 'smart fortwo Convertible 2012',
 'Spyker C8 Convertible 2009',
 'Spyker C8 Coupe 2009',
 'Suzuki Aerio Sedan 2007',
 'Suzuki Kizashi Sedan 2012',
 'Suzuki SX4 Hatchback 2012',
 'Suzuki SX4 Sedan 2012',
 'Tesla Model S Sedan 2012',
 'Toyota 4Runner SUV 2012',
 'Toyota Camry Sedan 2012',
 'Toyota Corolla Sedan 2012',
 'Toyota Sequoia SUV 2012',
 'Volkswagen Beetle Hatchback 2012',
 'Volkswagen Golf Hatchback 1991',
 'Volkswagen Golf Hatchback 2012',
 'Volvo 240 Sedan 1993',
 'Volvo C30 Hatchback 2012',
 'Volvo XC90 SUV 2007'}

# include = set(os.listdir(data_path))

resize_all(src=data_path, pklname=base_name, width=width, include=include)
# Out:
# Honda Accord Coupe 2012
# Rolls-Royce Phantom Drophead Coupe Convertible 2012
# Bentley Mulsanne Sedan 2011
# Dodge Charger SRT-8 2009
# GMC Terrain SUV 2012
# BMW 3 Series Wagon 2012
# GMC Acadia SUV 2012
# Toyota Corolla Sedan 2012
# Chevrolet Express Van 2007
# Aston Martin V8 Vantage Coupe 2012
# Mercedes-Benz E-Class Sedan 2012
# Acura TL Type-S 2008
# Rolls-Royce Phantom Sedan 2012
# Dodge Sprinter Cargo Van 2009
# Mercedes-Benz 300-Class Convertible 1993
# Jaguar XK XKR 2012
# Maybach Landaulet Convertible 2012
# Chevrolet Corvette Ron Fellows Edition Z06 2007
# Lamborghini Aventador Coupe 2012
# Fisker Karma Sedan 2012
# BMW 6 Series Convertible 2007
# Jeep Liberty SUV 2012
# Nissan 240SX Coupe 1998
# Rolls-Royce Ghost Sedan 2012
# Chevrolet Traverse SUV 2012
# Hyundai Santa Fe SUV 2012
# Audi TT RS Coupe 2012
# Hyundai Azera Sedan 2012
# Audi R8 Coupe 2012
# Dodge Caliber Wagon 2007
# Ferrari 458 Italia Convertible 2012
# Lamborghini Diablo Coupe 2001
# Ram C-V Cargo Van Minivan 2012
# Bentley Continental GT Coupe 2012
# Lincoln Town Car Sedan 2011
# BMW X3 SUV 2012
# Bentley Arnage Sedan 2009
# smart fortwo Convertible 2012
# Audi TT Hatchback 2011
# Audi S5 Convertible 2012
# BMW 1 Series Coupe 2012
# Dodge Ram Pickup 3500 Crew Cab 2010
# Dodge Caravan Minivan 1997
# Chevrolet Sonic Sedan 2012
# Tesla Model S Sedan 2012
# Audi 100 Sedan 1994
# Bentley Continental Flying Spur Sedan 2007
# Suzuki SX4 Sedan 2012
# Volkswagen Golf Hatchback 1991
# Lamborghini Reventon Coupe 2008
# Hyundai Tucson SUV 2012
# Daewoo Nubira Wagon 2002
# Mercedes-Benz S-Class Sedan 2012
#          'Aston Martin V8 Vantage Convertible ': 45,
#          'Aston Martin V8 Vantage Coupe ': 41,
#          'Aston Martin Virage Convertible ': 33,
#          'Aston Martin Virage Coupe ': 38,
#          'Audi 100 Sedan ': 41,
#          'Audi 100 Wagon ': 43,
#          'Audi A5 Coupe ': 41,
#          'Audi R8 Coupe ': 43,
#          'Audi RS 4 Convertible ': 37,
#          'Audi S4 Sedan ': 85,
#          'Audi S5 Convertible ': 42,
#          'Audi S5 Coupe ': 43,
#          'Audi S6 Sedan ': 46,
#          'Audi TT Hatchback ': 41,
#          'Audi TT RS Coupe ': 40,
#          'Audi TTS Coupe ': 43,
#          'Audi V8 Sedan ': 44,
#          'BMW 1 Series Convertible ': 36,
#          'BMW 1 Series Coupe ': 41,
#          'BMW 3 Series Sedan ': 43,
#          'BMW 3 Series Wagon ': 42,
#          'BMW 6 Series Convertible ': 44,
#          'BMW ActiveHybrid 5 Sedan ': 34,
#          'BMW M3 Coupe ': 45,
#          'BMW M5 Sedan ': 41,
#          'BMW M6 Convertible ': 41,
#          'BMW X3 SUV ': 39,
#          'BMW X5 SUV ': 42,
#          'BMW X6 SUV ': 42,
#          'BMW Z4 Convertible ': 41,
#          'Bentley Arnage Sedan ': 39,
#          'Bentley Continental Flying Spur Sedan ': 45,
#          'Bentley Continental GT Coupe ': 81,
#          'Bentley Continental Supersports Conv. Convertible ': 37,
#          'Bentley Mulsanne Sedan ': 36,
#          'Bugatti Veyron 16.4 Convertible ': 33,
#          'Bugatti Veyron 16.4 Coupe ': 44,
#          'Buick Enclave SUV ': 42,
#          'Buick Rainier SUV ': 43,
#          'Buick Regal GS ': 35,
#          'Buick Verano Sedan ': 38,
#          'Cadillac CTS-V Sedan ': 43,
#          'Cadillac Escalade EXT Crew Cab ': 45,
#          'Cadillac SRX SUV ': 41,
#          'Chevrolet Avalanche Crew Cab ': 45,
#          'Chevrolet Camaro Convertible ': 45,
#          'Chevrolet Cobalt SS ': 42,
#          'Chevrolet Corvette Convertible ': 40,
#          'Chevrolet Corvette Ron Fellows Edition Z06 ': 38,
#          'Chevrolet Corvette ZR1 ': 47,
#          'Chevrolet Express Cargo Van ': 30,
#          'Chevrolet Express Van ': 35,
#          'Chevrolet HHR SS ': 37,
#          'Chevrolet Impala Sedan ': 43,
#          'Chevrolet Malibu Hybrid Sedan ': 39,
#          'Chevrolet Malibu Sedan ': 45,
#          'Chevrolet Monte Carlo Coupe ': 45,
#          'Chevrolet Silverado 1500 Classic Extended Cab ': 43,
#          'Chevrolet Silverado 1500 Extended Cab ': 44,
#          'Chevrolet Silverado 1500 Hybrid Crew Cab ': 40,
#          'Chevrolet Silverado 1500 Regular Cab ': 44,
#          'Chevrolet Silverado 2500HD Regular Cab ': 38,
#          'Chevrolet Sonic Sedan ': 44,
#          'Chevrolet Tahoe Hybrid SUV ': 37,
#          'Chevrolet TrailBlazer SS ': 40,
#          'Chevrolet Traverse SUV ': 44,
#          'Chrysler 300 SRT-8 ': 49,
#          'Chrysler Aspen SUV ': 44,
#          'Chrysler Crossfire Convertible ': 43,
#          'Chrysler PT Cruiser Convertible ': 45,
#          'Chrysler Sebring Convertible ': 41,
#          'Chrysler Town and Country Minivan ': 38,
#          'Daewoo Nubira Wagon ': 45,
#          'Dodge Caliber Wagon ': 83,
#          'Dodge Caravan Minivan ': 44,
#          'Dodge Challenger SRT8 ': 39,
#          'Dodge Charger SRT-8 ': 42,
#          'Dodge Charger Sedan ': 41,
#          'Dodge Dakota Club Cab ': 39,
#          'Dodge Dakota Crew Cab ': 41,
#          'Dodge Durango SUV ': 90,
#          'Dodge Journey SUV ': 44,
#          'Dodge Magnum Wagon ': 40,
#          'Dodge Ram Pickup 3500 Crew Cab ': 43,
#          'Dodge Ram Pickup 3500 Quad Cab ': 44,
#          'Dodge Sprinter Cargo Van ': 40,
#          'Eagle Talon Hatchback ': 46,
#          'FIAT 500 Abarth ': 28,
#          'FIAT 500 Convertible ': 34,
#          'Ferrari 458 Italia Convertible ': 40,
#          'Ferrari 458 Italia Coupe ': 43,
#          'Ferrari California Convertible ': 39,
#          'Ferrari FF Coupe ': 42,
#          'Fisker Karma Sedan ': 44,
#          'Ford E-Series Wagon Van ': 38,
#          'Ford Edge SUV ': 43,
#          'Ford Expedition EL SUV ': 45,
#          'Ford F-150 Regular Cab ': 88,
#          'Ford F-450 Super Duty Crew Cab ': 42,
#          'Ford Fiesta Sedan ': 43,
#          'Ford Focus Sedan ': 45,
#          'Ford Freestar Minivan ': 44,
#          'Ford GT Coupe ': 46,
#          'Ford Mustang Convertible ': 45,
#          'Ford Ranger SuperCab ': 42,
#          'GMC Acadia SUV ': 45,
#          'GMC Canyon Extended Cab ': 40,
#          'GMC Savana Van ': 68,
#          'GMC Terrain SUV ': 42,
#          'GMC Yukon Hybrid SUV ': 43,
#          'Geo Metro Convertible ': 45,
#          'HUMMER H2 SUT Crew Cab ': 44,
#          'HUMMER H3T Crew Cab ': 39,
#          'Honda Accord Coupe ': 39,
#          'Honda Accord Sedan ': 39,
#          'Honda Odyssey Minivan ': 83,
#          'Hyundai Accent Sedan ': 24,
#          'Hyundai Azera Sedan ': 42,
#          'Hyundai Elantra Sedan ': 42,
#          'Hyundai Elantra Touring Hatchback ': 43,
#          'Hyundai Genesis Sedan ': 44,
#          'Hyundai Santa Fe SUV ': 42,
#          'Hyundai Sonata Hybrid Sedan ': 34,
#          'Hyundai Sonata Sedan ': 40,
#          'Hyundai Tucson SUV ': 44,
#          'Hyundai Veloster Hatchback ': 41,
#          'Hyundai Veracruz SUV ': 42,
#          'Infiniti G Coupe IPL ': 34,
#          'Infiniti QX56 SUV ': 33,
#          'Isuzu Ascender SUV ': 40,
#          'Jaguar XK XKR ': 47,
#          'Jeep Compass SUV ': 43,
#          'Jeep Grand Cherokee SUV ': 45,
#          'Jeep Liberty SUV ': 45,
#          'Jeep Patriot SUV ': 44,
#          'Jeep Wrangler SUV ': 43,
#          'Lamborghini Aventador Coupe ': 44,
#          'Lamborghini Diablo Coupe ': 45,
#          'Lamborghini Gallardo LP 570-4 Superleggera ': 36,
#          'Lamborghini Reventon Coupe ': 36,
#          'Land Rover LR2 SUV ': 43,
#          'Land Rover Range Rover SUV ': 43,
#          'Lincoln Town Car Sedan ': 39,
#          'MINI Cooper Roadster Convertible ': 37,
#          'Maybach Landaulet Convertible ': 29,
#          'Mazda Tribute SUV ': 36,
#          'McLaren MP4-12C Coupe ': 44,
#          'Mercedes-Benz 300-Class Convertible ': 48,
#          'Mercedes-Benz C-Class Sedan ': 46,
#          'Mercedes-Benz E-Class Sedan ': 44,
#          'Mercedes-Benz S-Class Sedan ': 45,
#          'Mercedes-Benz SL-Class Coupe ': 37,
#          'Mercedes-Benz Sprinter Van ': 41,
#          'Mitsubishi Lancer Sedan ': 48,
#          'Nissan 240SX Coupe ': 46,
#          'Nissan Juke Hatchback ': 44,
#          'Nissan Leaf Hatchback ': 42,
#          'Nissan NV Passenger Van ': 39,
#          'Plymouth Neon Coupe ': 44,
#          'Porsche Panamera Sedan ': 44,
#          'Ram C-V Cargo Van Minivan ': 41,
#          'Rolls-Royce Ghost Sedan ': 39,
#          'Rolls-Royce Phantom Drophead Coupe Convertible ': 31,
#          'Rolls-Royce Phantom Sedan ': 44,
#          'Scion xD Hatchback ': 42,
#          'Spyker C8 Convertible ': 45,
#          'Spyker C8 Coupe ': 43,
#          'Suzuki Aerio Sedan ': 38,
#          'Suzuki Kizashi Sedan ': 46,
#          'Suzuki SX4 Hatchback ': 42,
#          'Suzuki SX4 Sedan ': 41,
#          'Tesla Model S Sedan ': 39,
#          'Toyota 4Runner SUV ': 41,
#          'Toyota Camry Sedan ': 44,
#          'Toyota Corolla Sedan ': 44,
#          'Toyota Sequoia SUV ': 39,
#          'Volkswagen Beetle Hatchback ': 43,
#          'Volkswagen Golf Hatchback ': 89,
#          'Volvo 240 Sedan ': 46,
#          'Volvo C30 Hatchback ': 42,
#          'Volvo XC90 SUV ': 43,
#          'smart fortwo Convertible ': 40})

# %%
labels = np.unique(data['label'])
 

fig, axes = plt.subplots(1, len(labels))
fig.set_size_inches(15,4)
fig.tight_layout()
 
 

for ax, label in zip(axes, labels):
    idx = data['label'].index(label)
     
    ax.imshow(data['data'][idx])
    ax.axis('off')
    ax.set_title(label)

# %% [markdown]
# ### Code to remove incorrect data values

# %%
# copying the data into new placeholder
import copy

X_data = copy.deepcopy(data['data'])
y_data = copy.deepcopy(data['label'])
print(f"original length of data: X={len(X_data)}, y={len(y_data)}")
                    
# find the indexes which have the data without correct dimension
error_index = []
for i in range(len(X_data) - 1):
  if X_data[i].shape == (80, 80):
    error_index.append(i)

# separate data with incorrect dimension from overall list
final_X = []
final_y = []
for i, val in enumerate(X_data):
  if i not in error_index:
    final_X.append(val)

for i, val in enumerate(y_data):
  if i not in error_index:
    final_y.append(val)

print(f"Length of clean data: X={len(final_X)}, y={len(final_y)}")
# Out:
# original length of data: X=8144, y=8144
# Length of clean data: X=8126, y=8126

# %%
# X = np.array(data['data'])
# y = np.array(data['label'])

# use clean data instead
X = np.array(final_X)
y = np.array(final_y)

# %%
from sklearn.model_selection import train_test_split
 
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.2, 
    shuffle=True,
    random_state=42,
)

# %%
def plot_bar(y, loc='left', relative=True):
    width = 0.35
    if loc == 'left':
        n = -0.5
    elif loc == 'right':
        n = 0.5
     
    # calculate counts per type and sort, to ensure their order
    unique, counts = np.unique(y, return_counts=True)
    sorted_index = np.argsort(unique)
    unique = unique[sorted_index]
     
    if relative:
        # plot as a percentage
        counts = 100*counts[sorted_index]/len(y)
        ylabel_text = '% count'
    else:
        # plot counts
        counts = counts[sorted_index]
        ylabel_text = 'count'
         
    xtemp = np.arange(len(unique))
     
    plt.bar(xtemp + n*width, counts, align='center', alpha=.7, width=width)
    plt.xticks(xtemp, unique, rotation=45)
    plt.xlabel('equipment type')
    plt.ylabel(ylabel_text)
 
plt.suptitle('relative amount of photos per type')
plot_bar(y_train, loc='left')
plot_bar(y_test, loc='right')
plt.legend([
    'train ({0} photos)'.format(len(y_train)), 
    'test ({0} photos)'.format(len(y_test))
]);

# %%
#Processing Section

# %%
from skimage.feature import hog
from skimage.io import imread
from skimage.transform import rescale
 
bug = imread('archive/car_data/car_data/train/BMW X5 SUV 2007/00366.jpg',
             as_gray=True)

 

bug = rescale(bug, 1/3, mode='reflect')

bug_hog, bug_hog_img = hog(
    bug, pixels_per_cell=(14,14), 
    cells_per_block=(2, 2), 
    orientations=9, 
    visualize=True, 
    block_norm='L2-Hys')
 
fig, ax = plt.subplots(1,2)
fig.set_size_inches(8,6)

[a.tick_params(bottom=False, left=False, labelbottom=False, labelleft=False) 
    for a in ax]
 
ax[0].imshow(bug, cmap='gray')
ax[0].set_title('bug')
ax[1].imshow(bug_hog_img, cmap='gray')
ax[1].set_title('gub')
plt.show()

# %%
print('number of pixels: ', bug.shape[0] * bug.shape[1])
print('number of hog features: ', bug_hog.shape[0])
# Out:
# number of pixels:  21122
# number of hog features:  2772

# %%
#Transformers Section

# %%
from sklearn.base import BaseEstimator, TransformerMixin
 
class RGB2GrayTransformer(BaseEstimator, TransformerMixin):
   
 
    def __init__(self):
        pass
 
    def fit(self, X, y=None):
        
        return self
 
    def transform(self, X, y=None):
        
        return np.array([skimage.color.rgb2gray(img) for img in X])
     
 
class HogTransformer(BaseEstimator, TransformerMixin):
   
 
    def __init__(self, y=None, orientations=9,
                 pixels_per_cell=(8, 8),
                 cells_per_block=(3, 3), block_norm='L2-Hys'):
        self.y = y
        self.orientations = orientations
        self.pixels_per_cell = pixels_per_cell
        self.cells_per_block = cells_per_block
        self.block_norm = block_norm
 
    def fit(self, X, y=None):
        return self
 
    def transform(self, X, y=None):
 
        def local_hog(X):
            return hog(X,
                       orientations=self.orientations,
                       pixels_per_cell=self.pixels_per_cell,
                       cells_per_block=self.cells_per_block,
                       block_norm=self.block_norm)
 
        try: 
            return np.array([local_hog(img) for img in X])
        except:
            return np.array([local_hog(img) for img in X])

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.preprocessing import StandardScaler, Normalizer
import skimage
 

grayify = RGB2GrayTransformer()
hogify = HogTransformer(
    pixels_per_cell=(14, 14), 
    cells_per_block=(2,2), 
    orientations=9, 
    block_norm='L2-Hys'
)
scalify = StandardScaler()
 

X_train_gray = grayify.fit_transform(X_train)
X_train_hog = hogify.fit_transform(X_train_gray)
X_train_prepared = scalify.fit_transform(X_train_hog)
 
print(X_train_prepared.shape)
# Out:
# C:\Users\aatmc\AppData\Local\Temp/ipykernel_9544/3283533736.py:15: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   return np.array([skimage.color.rgb2gray(img) for img in X])
# (6515, 576)

# %%
#Training Section

# %%
#from sklearn.ensemble import RandomForestClassifier
#sgd_clf = SGDClassifier(random_state=42, max_iter=1000, tol=1e-3)
from sklearn.neural_network import MLPClassifier
#sgd_clf = RandomForestClassifier(n_estimators=100)
sgd_clf = MLPClassifier(solver='sgd')

sgd_clf.fit(X_train_prepared, y_train)
# Out:
# c:\users\aatmc\appdata\local\programs\python\python39\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(solver='sgd')

# %%
X_test_gray = grayify.transform(X_test)
X_test_hog = hogify.transform(X_test_gray)
X_test_prepared = scalify.transform(X_test_hog)
# Out:
# C:\Users\aatmc\AppData\Local\Temp/ipykernel_9544/3283533736.py:15: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   return np.array([skimage.color.rgb2gray(img) for img in X])

# %%
y_pred = sgd_clf.predict(X_test_prepared)
print(np.array(y_pred == y_test)[:25])
print('')
print('Percentage correct: ', 100*np.sum(y_pred == y_test)/len(y_test))
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False]
#
# Percentage correct:  3.867403314917127

# %%
#confusion Matrix Section

# %%
import pandas as pd

# %%
labels = y_test
predictions = y_pred
 
# put the data in a dataframe for pretty printing
df = pd.DataFrame(
    np.c_[labels, predictions], 
    columns=['true_label', 'prediction']
)
df
# Out:
#                                  true_label  \
# 0                    Spyker C8 Convertible
# 1                           Audi 100 Sedan
# 2                     Suzuki SX4 Hatchback
# 3                            Ford Edge SUV
# 4           Dodge Ram Pickup 3500 Crew Cab
# ...                                     ...
# 1624                  Toyota Corolla Sedan
# 1625                 McLaren MP4-12C Coupe
# 1626                   Volvo C30 Hatchback
# 1627  Chevrolet Silverado 1500 Regular Cab
# 1628   Aston Martin V8 Vantage Convertible
#
#                                        prediction
# 0            Aston Martin V8 Vantage Convertible
# 1                               Audi TT RS Coupe
# 2                          Dodge Dakota Club Cab
# 3                      Aston Martin Virage Coupe
# 4                             Chrysler Aspen SUV
# ...                                           ...
# 1624                      Lincoln Town Car Sedan
# 1625                          BMW 3 Series Sedan
# 1626                            Chevrolet HHR SS
# 1627                          Toyota Sequoia SUV
# 1628  Chevrolet Corvette Ron Fellows Edition Z06
#
# [1629 rows x 2 columns]

# %%
print(y)
# Out:
# ['Acura Integra Type R ' 'Acura Integra Type R ' 'Acura Integra Type R '
#  ... 'Volvo XC90 SUV ' 'Volvo XC90 SUV ' 'Volvo XC90 SUV ']

# %%
#print(X[1110])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9544/3840192594.py in <module>
# ----> 1 print(X[1110])
#
# NameError: name 'X' is not defined

# %%
print(data['data'][1110])

# %%
print(len(X))

# %%
print(len(data['data']))

# %%
#os.remove(pklname)
